# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mhassantariqofficial/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I selected the **Content Refresh Prioritization** lane.
#
# I chose this lane because the starter notebooks showed that some pages lose performance over time. Instead of updating every page, machine learning can help identify which pages should be reviewed first. This can save time and help content teams focus on high-impact pages.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# **Question**
#
# Which web pages should be prioritized for content refresh based on their historical search performance?
#
# **Decision**
#
# Decide which pages should be reviewed first.
#
# **Action**
#
# The SEO or content team updates the highest-priority pages.
#
# **Cost of a wrong recommendation**
#
# If the wrong pages are selected, valuable pages may continue to lose traffic while time is spent updating pages that do not need attention.
#
# **Why Machine Learning?**
#
# Machine learning can combine multiple signals such as impressions, CTR, page age, and average position to rank pages more effectively than a simple hand-written rule.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/mhassantariqofficial/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)

print("Current directory:", os.getcwd())
# Out:
# Current directory: /content/flyrank-ml-internship

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

print("Total pages:", len(df))
print("Average CTR:", round(df["ctr"].mean(),3))
print("Average Search Volume:", round(df["search_volume"].mean(),2))
print("Declining Pages:", (df["trend_direction"]=="down").sum())
# Out:
# Total pages: 30000
# Average CTR: 0.511
# Average Search Volume: 158.88
# Declining Pages: 16262

# %% [markdown]
# ### Observations
#
# - The starter dataset contains 30,000 pages.
# - Many pages are marked as declining.
# - The dataset includes useful signals such as CTR, impressions, average position, and content age that can help prioritize content refresh.

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This project does not predict Google's algorithm.
#
# The results are based only on the provided anonymized dataset and should be treated as decision support rather than absolute truth.
#
# The model provides recommendations that should be reviewed by humans before making business decisions.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.

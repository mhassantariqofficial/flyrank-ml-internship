# %% [markdown]
# # ML-03 — Frame Your Lane as an ML Task
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/mhassantariqofficial/flyrank-ml-internship/blob/main/work/notebooks/w02_ml_task_framing.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os, sys, subprocess

IN_COLAB = "google.colab" in sys.modules
REPO_URL = "https://github.com/flyrank-bih/flyrank-ml-internship-starter"
REPO_DIR = "flyrank-ml-internship-starter"

if IN_COLAB:
    if not os.path.isdir(REPO_DIR):
        subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
    os.chdir(REPO_DIR)
    subprocess.run([sys.executable, "-m", "pip", "install", "-q", "-r", "requirements.txt"], check=True)
elif os.path.basename(os.getcwd()) == "notebooks":
    os.chdir("..")

# %% [markdown]
# ## 1. My lane as an ML task (type)
#
# *Classification, clustering, ranking, or scoring — which one, and why?*

# %%
My chosen lane is identifying webpages that are likely to decline in search performance.

This is a Classification problem because the model predicts whether a webpage is declining or not declining.

# %% [markdown]
# ## 2. Target or proxy
#
# *What would you predict? Where does that label come from — observed outcome or a defined rule?*

# %%
The target is `is_declining_label`.

This target identifies whether a webpage is declining in search performance. It is created from the `trend_direction` column, where pages with the value `down` are labeled as 1 (declining) and all other pages are labeled as 0 (not declining).

# %% [markdown]
# ## 3. Success metric
#
# *One metric you can defend. What number means 'good'?*

# %%
The success metric for this project is Precision@50.

Precision@50 measures how many of the top 50 webpages selected by the model are actually declining. A higher Precision@50 means the model is better at identifying the pages that should be reviewed first.

# %% [markdown]
# ## 4. The unit of analysis, as a real dataframe
#
# *Load your lane's slice and show it: one row = one what?*

# %%
import os
print(os.getcwd())
# Out:
# /content/flyrank-ml-internship-starter/flyrank-ml-internship-starter

# %%
import pandas as pd

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df["is_declining_label"] = (df["trend_direction"] == "down").astype(int)

df[[
    "content_age_days",
    "days_since_last_update",
    "impressions_90d",
    "ctr",
    "trend_direction",
    "is_declining_label"
]].head()
# Out:
#    content_age_days  days_since_last_update  impressions_90d   ctr  \
# 0               187                      20             3803  0.76
# 1               445                      25            15320  0.05
# 2               141                      20            12581  0.09
# 3               463                      22            11751  0.49
# 4               263                      14            19140  0.13
#
#   trend_direction  is_declining_label
# 0            down                   1
# 1            down                   1
# 2            down                   1
# 3          stable                   0
# 4            down                   1

# %%
print("Unit of Analysis: One row represents one webpage.\n")

df[[
    "content_age_days",
    "days_since_last_update",
    "impressions_90d",
    "avg_position",
    "ctr",
    "is_declining_label"
]].head()
# Out:
# Unit of Analysis: One row represents one webpage.
#    content_age_days  days_since_last_update  impressions_90d  avg_position  \
# 0               187                      20             3803          10.6
# 1               445                      25            15320          20.3
# 2               141                      20            12581          36.5
# 3               463                      22            11751           6.2
# 4               263                      14            19140          44.0
#
#     ctr  is_declining_label
# 0  0.76                   1
# 1  0.05                   1
# 2  0.09                   1
# 3  0.49                   0
# 4  0.13                   1

# %% [markdown]
# ## 5. Why ML beats a fixed rule here
#
# *What makes the pattern too messy for an if-statement?*

# %%
A fixed rule uses only one or two conditions and may miss important patterns in the data. Machine Learning can learn relationships between multiple features such as content age, impressions, average position, CTR, and update history. This allows the model to make better decisions and improve prediction accuracy compared to a simple hand-written rule.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
